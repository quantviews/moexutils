# %%
# moex_utils лежит в корне проекта
import sys
sys.path.insert(0, '..')

# %%
import moex_utils as moex
import pandas as pd

# %%
div_folder = 'G:/YandexDisk/FINANCE/dividends/data/'
moex.add_adj_close_to_all_stocks(div_folder)
# Out:
# Found 100 stocks to process for adjusted close calculation.
# Processing AFKS...
# Successfully updated AFKS with adj_close column.
# Processing AFLT...
# Successfully updated AFLT with adj_close column.
# Processing AGRO...
# Successfully updated AGRO with adj_close column.
# Processing AKRN...
# Successfully updated AKRN with adj_close column.
# Processing ALRS...
# Successfully updated ALRS with adj_close column.
# Processing ASTR...
# Info: No dividend file found for ASTR at G:/YandexDisk/FINANCE/dividends/data/ASTR.csv. Setting adj_close equal to close.
# Successfully updated ASTR with adj_close column.
# Processing BANE...
# Successfully updated BANE with adj_close column.
# Processing BANEP...
# Successfully updated BANEP with adj_close column.
# Processing BSPB...
# Successfully updated BSPB with adj_close column.
# Processing CBOM...
# Successfully updated CBOM with adj_close column.
# Processing CHMF...
# Successfully updated CHMF with adj_close column.
# Processing CNRU...
# Info: No dividend file found for CNRU at G:/YandexDisk/FINANCE/dividends/data/CNRU.csv. Setting adj_close equal to close.
# Successfully updated CNRU with adj_close column.
# Processing DIXY...
# Info: No dividend file found for DIXY at G:/YandexDisk/FINANCE/dividends/data/DIXY.csv. Setting adj_close equal to close.
# Successfully updated DIXY with adj_close column.
# Processing DOMRF...
# Info: No dividend file found for DOMRF at G:/YandexDisk/FINANCE/dividends/data/DOMRF.csv. Setting adj_close equal to close.
# Successfully updated DOMRF with adj_close column.
# Processing DSKY...
# Successfully updated DSKY with adj_close column.
# Processing ENPG...
# Info: No dividend file found for ENPG at G:/YandexDisk/FINANCE/dividends/data/ENPG.csv. Setting adj_close equal to close.
# Successfully updated ENPG with adj_close column.
# Processing EONR...
# Info: No dividend file found for EONR at G:/YandexDisk/FINANCE/dividends/data/EONR.csv. Setting adj_close equal to close.
# Successfully updated EONR with adj_close column.
# Processing EPLN...
# Info: No dividend file found for EPLN at G:/YandexDisk/FINANCE/dividends/data/EPLN.csv. Setting adj_close equal to close.
# Successfully updated EPLN with adj_close column.
# Processing FEES...
# Successfully updated FEES with adj_close column.
# Processing FIVE...
# Successfully updated FIVE with adj_close column.
# Processing FIXP...
# Info: No dividend file found for FIXP at G:/YandexDisk/FINANCE/dividends/data/FIXP.csv. Setting adj_close equal to close.
# Successfully updated FIXP with adj_close column.
# Processing FLOT...
# Successfully updated FLOT with adj_close column.
# Processing GAZP...
# Successfully updated GAZP with adj_close column.
# Processing GCHE...
# Successfully updated GCHE with adj_close column.
# Processing GLTR...
# Successfully updated GLTR with adj_close column.
# Processing GMKN...
# Successfully updated GMKN with adj_close column.
# Processing HEAD...
# Info: No dividend file found for HEAD at G:/YandexDisk/FINANCE/dividends/data/HEAD.csv. Setting adj_close equal to close.
# Successfully updated HEAD with adj_close column.
# Processing HHRU...
# Successfully updated HHRU with adj_close column.
# Processing HYDR...
# Successfully updated HYDR with adj_close column.
# Processing IRAO...
# Successfully updated IRAO with adj_close column.
# Processing KMAZ...
# Successfully updated KMAZ with adj_close column.
# Processing LEAS...
# Successfully updated LEAS with adj_close column.
# Processing LKOH...
# Successfully updated LKOH with adj_close column.
# Processing LNTA...
# Info: No dividend file found for LNTA at G:/YandexDisk/FINANCE/dividends/data/LNTA.csv. Setting adj_close equal to close.
# Successfully updated LNTA with adj_close column.
# Processing LSRG...
# Successfully updated LSRG with adj_close column.
# Processing MAGN...
# Successfully updated MAGN with adj_close column.
# Processing MAIL...
# Info: No dividend file found for MAIL at G:/YandexDisk/FINANCE/dividends/data/MAIL.csv. Setting adj_close equal to close.
# Successfully updated MAIL with adj_close column.
# Processing MDMG...
# Successfully updated MDMG with adj_close column.
# Processing MFON...
# Info: No dividend file found for MFON at G:/YandexDisk/FINANCE/dividends/data/MFON.csv. Setting adj_close equal to close.
# Successfully updated MFON with adj_close column.
# Processing MGNT...
# Successfully updated MGNT with adj_close column.
# Processing MOEX...
# Successfully updated MOEX with adj_close column.
# Processing MRKH...
# Info: No dividend file found for MRKH at G:/YandexDisk/FINANCE/dividends/data/MRKH.csv. Setting adj_close equal to close.
# Successfully updated MRKH with adj_close column.
# Processing MSNG...
# Successfully updated MSNG with adj_close column.
# Processing MSRS...
# Successfully updated MSRS with adj_close column.
# Processing MSTT...
# Successfully updated MSTT with adj_close column.
# Processing MTLR...
# Successfully updated MTLR with adj_close column.
# Processing MTLRP...
# Successfully updated MTLRP with adj_close column.
# Processing MTSS...
# Successfully updated MTSS with adj_close column.
# Processing MVID...
# Successfully updated MVID with adj_close column.
# Processing NKNC...
# Successfully updated NKNC with adj_close column.
# Processing NLMK...
# Successfully updated NLMK with adj_close column.
# Processing NMTP...
# Successfully updated NMTP with adj_close column.
# Processing NVTK...
# Successfully updated NVTK with adj_close column.
# Processing OGKB...
# Successfully updated OGKB with adj_close column.
# Processing OZON...
# Info: No dividend file found for OZON at G:/YandexDisk/FINANCE/dividends/data/OZON.csv. Setting adj_close equal to close.
# Successfully updated OZON with adj_close column.
# Processing PGIL...
# Info: No dividend file found for PGIL at G:/YandexDisk/FINANCE/dividends/data/PGIL.csv. Setting adj_close equal to close.
# Successfully updated PGIL with adj_close column.
# Processing PHOR...
# Successfully updated PHOR with adj_close column.
# Processing PHST...
# Info: No dividend file found for PHST at G:/YandexDisk/FINANCE/dividends/data/PHST.csv. Setting adj_close equal to close.
# Successfully updated PHST with adj_close column.
# Processing PIKK...
# Successfully updated PIKK with adj_close column.
# Processing PLZL...
# Successfully updated PLZL with adj_close column.
# Processing POGR...
# Info: No dividend file found for POGR at G:/YandexDisk/FINANCE/dividends/data/POGR.csv. Setting adj_close equal to close.
# Successfully updated POGR with adj_close column.
# Processing POLY...
# Successfully updated POLY with adj_close column.
# Processing POSI...
# Successfully updated POSI with adj_close column.
# Processing QIWI...
# Successfully updated QIWI with adj_close column.
# Processing RASP...
# Successfully updated RASP with adj_close column.
# Processing RENI...
# Successfully updated RENI with adj_close column.
# Processing RNFT...
# Info: No dividend file found for RNFT at G:/YandexDisk/FINANCE/dividends/data/RNFT.csv. Setting adj_close equal to close.
# Successfully updated RNFT with adj_close column.
# Processing ROSN...
# Successfully updated ROSN with adj_close column.
# Processing RSTI...
# Successfully updated RSTI with adj_close column.
# Processing RTKM...
# Successfully updated RTKM with adj_close column.
# Processing RTKMP...
# Successfully updated RTKMP with adj_close column.
# Processing RUAL...
# Successfully updated RUAL with adj_close column.
# Processing RUALR...
# Info: No dividend file found for RUALR at G:/YandexDisk/FINANCE/dividends/data/RUALR.csv. Setting adj_close equal to close.
# Successfully updated RUALR with adj_close column.
# Processing SBER...
# Successfully updated SBER with adj_close column.
# Processing SBERP...
# Successfully updated SBERP with adj_close column.
# Processing SELG...
# Successfully updated SELG with adj_close column.
# Processing SFIN...
# Successfully updated SFIN with adj_close column.
# Processing SGZH...
# Successfully updated SGZH with adj_close column.
# Processing SMLT...
# Successfully updated SMLT with adj_close column.
# Processing SNGS...
# Successfully updated SNGS with adj_close column.
# Processing SNGSP...
# Successfully updated SNGSP with adj_close column.
# Processing SVAV...
# Successfully updated SVAV with adj_close column.
# Processing SVCB...
# Successfully updated SVCB with adj_close column.
# Processing T...
# Successfully updated T with adj_close column.
# Processing TATN...
# Successfully updated TATN with adj_close column.
# Processing TATNP...
# Successfully updated TATNP with adj_close column.
# Processing TCSG...
# Info: No dividend file found for TCSG at G:/YandexDisk/FINANCE/dividends/data/TCSG.csv. Setting adj_close equal to close.
# Successfully updated TCSG with adj_close column.
# Processing TNBPP...
# Info: No dividend file found for TNBPP at G:/YandexDisk/FINANCE/dividends/data/TNBPP.csv. Setting adj_close equal to close.
# Successfully updated TNBPP with adj_close column.
# Processing TRMK...
# Successfully updated TRMK with adj_close column.
# Processing TRNFP...
# Successfully updated TRNFP with adj_close column.
# Processing UGLD...
# Info: No dividend file found for UGLD at G:/YandexDisk/FINANCE/dividends/data/UGLD.csv. Setting adj_close equal to close.
# Successfully updated UGLD with adj_close column.
# Processing UPRO...
# Successfully updated UPRO with adj_close column.
# Processing URKA...
# Successfully updated URKA with adj_close column.
# Processing UWGN...
# Info: No dividend file found for UWGN at G:/YandexDisk/FINANCE/dividends/data/UWGN.csv. Setting adj_close equal to close.
# Successfully updated UWGN with adj_close column.
# Processing VKCO...
# Info: No dividend file found for VKCO at G:/YandexDisk/FINANCE/dividends/data/VKCO.csv. Setting adj_close equal to close.
# Successfully updated VKCO with adj_close column.
# Processing VSMO...
# Successfully updated VSMO with adj_close column.
# Processing VTBR...
# Successfully updated VTBR with adj_close column.
# Processing VZRZ...
# Successfully updated VZRZ with adj_close column.
# Processing YDEX...
# Successfully updated YDEX with adj_close column.
# Processing YNDX...
# Info: No dividend file found for YNDX at G:/YandexDisk/FINANCE/dividends/data/YNDX.csv. Setting adj_close equal to close.
# Successfully updated YNDX with adj_close column.
#
# Completed processing for 100 stocks.
