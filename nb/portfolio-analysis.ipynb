# %%
# moex_utils лежит в корне проекта
import sys
sys.path.insert(0, '..')

# %% [markdown]
# # Анализ и сравнение акций между собой

# %%
import moex_utils as moex
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Combine all stock data
combined_stocks = moex.combine_moex_stocks()
# Out:
# Loaded data for AFKS
# Loaded data for AFLT
# Loaded data for AGRO
# Loaded data for AKRN
# Loaded data for ALRS
# Loaded data for ASTR
# Loaded data for BANE
# Loaded data for BANEP
# Loaded data for BSPB
# Loaded data for CBOM
# Loaded data for CHMF
# Loaded data for CNRU
# Loaded data for DIXY
# Loaded data for DOMRF
# Loaded data for DSKY
# Loaded data for ENPG
# Loaded data for EONR
# Loaded data for EPLN
# Loaded data for FEES
# Loaded data for FIVE
# Loaded data for FIXP
# Loaded data for FLOT
# Loaded data for GAZP
# Loaded data for GCHE
# Loaded data for GLTR
# Loaded data for GMKN
# Loaded data for HEAD
# Loaded data for HHRU
# Loaded data for HYDR
# Loaded data for IRAO
# Loaded data for KMAZ
# Loaded data for LEAS
# Loaded data for LKOH
# Loaded data for LNTA
# Loaded data for LSRG
# Loaded data for MAGN
# Loaded data for MAIL
# Loaded data for MDMG
# Loaded data for MFON
# Loaded data for MGNT
# Loaded data for MOEX
# Loaded data for MRKH
# Loaded data for MSNG
# Loaded data for MSRS
# Loaded data for MSTT
# Loaded data for MTLR
# Loaded data for MTLRP
# Loaded data for MTSS
# Loaded data for MVID
# Loaded data for NKNC
# Loaded data for NLMK
# Loaded data for NMTP
# Loaded data for NVTK
# Loaded data for OGKB
# Loaded data for OZON
# Loaded data for PGIL
# Loaded data for PHOR
# Loaded data for PHST
# Loaded data for PIKK
# Loaded data for PLZL
# Loaded data for POGR
# Loaded data for POLY
# Loaded data for POSI
# Loaded data for QIWI
# Loaded data for RASP
# Loaded data for RENI
# Loaded data for RNFT
# Loaded data for ROSN
# Loaded data for RSTI
# Loaded data for RTKM
# Loaded data for RTKMP
# Loaded data for RUAL
# Loaded data for RUALR
# Loaded data for SBER
# Loaded data for SBERP
# Loaded data for SELG
# Loaded data for SFIN
# Loaded data for SGZH
# Loaded data for SMLT
# Loaded data for SNGS
# Loaded data for SNGSP
# Loaded data for SVAV
# Loaded data for SVCB
# Loaded data for T
# Loaded data for TATN
# Loaded data for TATNP
# Loaded data for TCSG
# Loaded data for TNBPP
# Loaded data for TRMK
# Loaded data for TRNFP
# Loaded data for UGLD
# Loaded data for UPRO
# Loaded data for URKA
# Loaded data for UWGN
# Loaded data for VKCO
# Loaded data for VSMO
# Loaded data for VTBR
# Loaded data for VZRZ
# Loaded data for YDEX
# Loaded data for YNDX
#
# Combined 100 stocks into unified dataset
# Total rows: 317249
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Combine all stock data
#       2 combined_stocks = moex.combine_moex_stocks()
# ----> 3 head()
#
# NameError: name 'head' is not defined

# %%
combined_stocks.head()
write_csv
# Out:
#               open   close   high     low   value_rub     volume ticker  \
# date
# 2007-12-12  43.000  41.449  43.00  41.000  19220036.9   465200.0   AFKS
# 2007-12-13  41.200  40.896  41.20  40.000  23833797.3   585400.0   AFKS
# 2007-12-14  40.985  41.797  42.35  40.000  53235298.6  1284700.0   AFKS
# 2007-12-17  41.890  41.900  43.00  41.101  53691481.8  1276500.0   AFKS
# 2007-12-18  41.001  41.400  42.89  41.000  34289032.7   817900.0   AFKS
#
#             adj_close
# date
# 2007-12-12  27.193086
# 2007-12-13  26.830284
# 2007-12-14  27.421396
# 2007-12-17  27.488970
# 2007-12-18  27.160939

# %%
combined_stocks.to_csv("combined_stocks.csv", index=False)
